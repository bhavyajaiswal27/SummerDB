# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df1 = pd.read_csv(r"C:\Users\jaisw\Downloads\playground-series-s5e2\train.csv")
df1.head()
# Out:
#    id         Brand Material    Size  Compartments Laptop Compartment  \
# 0   0      Jansport  Leather  Medium           7.0                Yes
# 1   1      Jansport   Canvas   Small          10.0                Yes
# 2   2  Under Armour  Leather   Small           2.0                Yes
# 3   3          Nike    Nylon   Small           8.0                Yes
# 4   4        Adidas   Canvas  Medium           1.0                Yes
#
#   Waterproof      Style  Color  Weight Capacity (kg)      Price
# 0         No       Tote  Black             11.611723  112.15875
# 1        Yes  Messenger  Green             27.078537   68.88056
# 2         No  Messenger    Red             16.643760   39.17320
# 3         No  Messenger  Green             12.937220   80.60793
# 4        Yes  Messenger  Green             17.749338   86.02312

# %%
df3 = pd.read_csv(r"C:\Users\jaisw\Downloads\playground-series-s5e2\test.csv")
df3.head()
# Out:
#        id   Brand Material    Size  Compartments Laptop Compartment  \
# 0  300000    Puma  Leather   Small           2.0                 No
# 1  300001    Nike   Canvas  Medium           7.0                 No
# 2  300002  Adidas   Canvas   Large           9.0                 No
# 3  300003  Adidas    Nylon   Large           1.0                Yes
# 4  300004     NaN    Nylon   Large           2.0                Yes
#
#   Waterproof      Style  Color  Weight Capacity (kg)
# 0         No       Tote  Green             20.671147
# 1        Yes   Backpack  Green             13.564105
# 2        Yes  Messenger   Blue             11.809799
# 3         No  Messenger  Green             18.477036
# 4        Yes       Tote  Black              9.907953

# %%
df2 = pd.read_csv(r"C:\Users\jaisw\Downloads\playground-series-s5e2\training_extra.csv")
df2.head()
# Out:
#        id         Brand   Material   Size  Compartments Laptop Compartment  \
# 0  500000  Under Armour     Canvas  Small          10.0                Yes
# 1  500001          Puma  Polyester  Small           4.0                 No
# 2  500002      Jansport  Polyester  Small           8.0                Yes
# 3  500003          Nike      Nylon  Large           7.0                 No
# 4  500004          Nike    Leather  Large           9.0                 No
#
#   Waterproof      Style  Color  Weight Capacity (kg)      Price
# 0        Yes       Tote   Blue             23.882052  114.11068
# 1        Yes   Backpack  Green             11.869095  129.74972
# 2        Yes       Tote    Red              8.092302   21.37370
# 3         No  Messenger   Pink              7.719581   48.09209
# 4        Yes       Tote  Green             22.741826   77.32461

# %%
df2.shape
# Out:
# (3694318, 11)

# %%
df1.shape
# Out:
# (300000, 11)

# %%
df3.shape
# Out:
# (200000, 10)

# %%
print(df1['Waterproof'].unique())
# Out:
# ['No' 'Yes' nan]

# %%
df1.dropna(how='any', inplace=True)
df1.shape
# Out:
# (246686, 11)

# %%
df1['Compartments'].dtypes
# Out:
# dtype('float64')

# %%
col = df1.columns
col
# Out:
# Index(['id', 'Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)', 'Price'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['id', 'Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)'],
#       dtype='object')

# %%
label = LabelEncoder()

coll = ['Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment', 'Waterproof', 'Style', 'Color'] 

for coli in coll:
    df3[coli] = label.fit_transform(df3[coli])

df3.head()
# Out:
#        id  Brand  Material  Size  Compartments  Laptop Compartment  \
# 0  300000      3         1     2             1                   0
# 1  300001      2         0     1             6                   0
# 2  300002      0         0     0             8                   0
# 3  300003      0         2     0             0                   1
# 4  300004      5         2     0             1                   1
#
#    Waterproof  Style  Color  Weight Capacity (kg)
# 0           0      2      3             20.671147
# 1           1      0      3             13.564105
# 2           1      1      1             11.809799
# 3           0      1      3             18.477036
# 4           1      2      0              9.907953

# %%
minimaxi = MinMaxScaler()

df3['Weight Capacity (kg)'] = minimaxi.fit_transform(df3[['Weight Capacity (kg)']])
df1['Weight Capacity (kg)']
df1['Price'] = minimaxi.fit_transform(df1[['Price']])
df1['Price']
# Out:
# 0         0.719694
# 1         0.399115
# 2         0.179061
# 3         0.485985
# 4         0.526097
#             ...
# 299995    0.851833
# 299996    0.035987
# 299997    0.714175
# 299998    0.747339
# 299999    0.086871
# Name: Price, Length: 246686, dtype: float64

# %%
X = df1.drop('Price', axis=1)
y = df1['Price']

# %%
xtest = df3

# %%
from sklearn import tree

model = tree.DecisionTreeRegressor()

# %%
model.fit(X, y)
# Out:
# DecisionTreeRegressor()

# %%
ypred = model.predict(xtest)

# %%
output_df = pd.DataFrame({'id': df3['id'], 'Calories': ypred})
output_df.to_csv('output.csv', index=False)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\SummerDB\CaloriePredictionKaggle\train.csv")
df.head()
# Out:
#    id     Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 0   0    male   36   189.0    82.0      26.0       101.0       41.0     150.0
# 1   1  female   64   163.0    60.0       8.0        85.0       39.7      34.0
# 2   2  female   51   161.0    64.0       7.0        84.0       39.8      29.0
# 3   3    male   20   192.0    90.0      25.0       105.0       40.7     140.0
# 4   4  female   38   166.0    61.0      25.0       102.0       40.6     146.0

# %%
df1 = pd.read_csv(r"C:\SummerDB\CaloriePredictionKaggle\test.csv")
df1.head()
# Out:
#        id     Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0  750000    male   45   177.0    81.0       7.0        87.0       39.8
# 1  750001    male   26   200.0    97.0      20.0       101.0       40.5
# 2  750002  female   29   188.0    85.0      16.0       102.0       40.4
# 3  750003  female   39   172.0    73.0      20.0       107.0       40.6
# 4  750004  female   30   173.0    67.0      16.0        94.0       40.5

# %%
#didnt use

df['Sex'] = df['Sex'].apply(lambda x: 0 if x == 'male' else 1)
df.head()
# Out:
#        id  Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0  750000    1   45   177.0    81.0       7.0        87.0       39.8
# 1  750001    1   26   200.0    97.0      20.0       101.0       40.5
# 2  750002    1   29   188.0    85.0      16.0       102.0       40.4
# 3  750003    1   39   172.0    73.0      20.0       107.0       40.6
# 4  750004    1   30   173.0    67.0      16.0        94.0       40.5

# %%
print(df.columns)
print(df.shape)
# Out:
# Index(['id', 'Sex', 'Age', 'Height', 'Weight', 'Duration', 'Heart_Rate',
#        'Body_Temp', 'Calories'],
#       dtype='object')
# (750000, 9)

# %%
#didnt use

from sklearn.preprocessing import OneHotEncoder

df = pd.get_dummies(df, columns=['Sex'], drop_first=True)
df.head()
# Out:
#        id  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Sex_male
# 0  750000   45   177.0    81.0       7.0        87.0       39.8      True
# 1  750001   26   200.0    97.0      20.0       101.0       40.5      True
# 2  750002   29   188.0    85.0      16.0       102.0       40.4     False
# 3  750003   39   172.0    73.0      20.0       107.0       40.6     False
# 4  750004   30   173.0    67.0      16.0        94.0       40.5     False

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['Sex'] = label_encoder.fit_transform(df['Sex'])
df1['Sex'] = label_encoder.fit_transform(df1['Sex'])

# %%
df['Sex'].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    id  Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 0   0    1   36   189.0    82.0      26.0       101.0       41.0     150.0
# 1   1    0   64   163.0    60.0       8.0        85.0       39.7      34.0
# 2   2    0   51   161.0    64.0       7.0        84.0       39.8      29.0
# 3   3    1   20   192.0    90.0      25.0       105.0       40.7     140.0
# 4   4    0   38   166.0    61.0      25.0       102.0       40.6     146.0

# %%
df1.head()
# Out:
#        id  Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0  750000    1   45   177.0    81.0       7.0        87.0       39.8
# 1  750001    1   26   200.0    97.0      20.0       101.0       40.5
# 2  750002    0   29   188.0    85.0      16.0       102.0       40.4
# 3  750003    0   39   172.0    73.0      20.0       107.0       40.6
# 4  750004    0   30   173.0    67.0      16.0        94.0       40.5

# %%
for col in df.columns:
    print(col, df[col].isnull().sum())
# Out:
# id 0
# Sex 0
# Age 0
# Height 0
# Weight 0
# Duration 0
# Heart_Rate 0
# Body_Temp 0

# %%
def detect_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers

for col in df.columns:
    # if col != Sex and col != id:
    outliers = detect_outliers_iqr(df, col)
    print(f"{col}: {len(outliers)} outliers")
print(" ")
print("break")

for col in df1.columns:
    # if col != Sex and col != id:
    outliers = detect_outliers_iqr(df1, col)
    print(f"{col}: {len(outliers)} outliers")
# Out:
# id: 0 outliers
# Sex: 0 outliers
# Age: 0 outliers
# Height: 14 outliers
# Weight: 9 outliers
# Duration: 0 outliers
# Heart_Rate: 36 outliers
# Body_Temp: 14919 outliers
# Calories: 139 outliers
#
# break
# id: 0 outliers
# Sex: 0 outliers
# Age: 0 outliers
# Height: 6 outliers
# Weight: 1 outliers
# Duration: 0 outliers
# Heart_Rate: 13 outliers
# Body_Temp: 6241 outliers

# %%
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return df[(df[column] >= lower) & (df[column] <= upper)]

for col in df.columns:
    if col != 'Calories' and col != 'Sex' and col != 'id':
        df = remove_outliers_iqr(df, col)

# %%
for col in df1.columns:
    if col != 'Sex' and col != 'id':
        df1 = remove_outliers_iqr(df1, col)

# %%
df1.shape
# Out:
# (243740, 8)

# %%
def values(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    print(column , Q1, Q3, IQR, lower, upper)
    
for col in df.columns:
    values(df, col)
# Out:
# id 187481.25 562468.75 374987.5 -375000.0 1124950.0
# Sex 0.0 1.0 1.0 -1.5 2.5
# Age 28.0 52.0 24.0 -8.0 88.0
# Height 164.0 185.0 21.0 132.5 216.5
# Weight 63.0 87.0 24.0 27.0 123.0
# Duration 9.0 23.0 14.0 -12.0 44.0
# Heart_Rate 89.0 103.0 14.0 68.0 124.0
# Body_Temp 39.7 40.7 1.0 38.2 42.2
# Calories 36.0 137.0 101.0 -115.5 288.5

# %%
df.columns
df.target
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9108\597754435.py in ?()
#       1 df.columns
# ----> 2 df.target
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'target'

# %%
X = df.drop({'Calories', 'id'}, axis=1)
Y = df['Calories']

from sklearn import linear_model

reg=linear_model.LinearRegression()

reg.fit(X,Y)
# Out:
# LinearRegression()

# %%
df11 = df1.drop(columns=['id'])
y_pred = reg.predict(df11)
for i in range(len(y_pred)):
    if y_pred[i] < 0:
        y_pred[i] = 0

# %%
output_df = pd.DataFrame({'id': df1['id'], 'Calories': y_pred})
output_df.to_csv('output.csv', index=False)

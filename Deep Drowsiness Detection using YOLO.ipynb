# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
torch.__version__
# Out:
# '2.7.1+cpu'

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import torch

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\jaisw/.cache\torch\hub\ultralytics_yolov5_master
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:27
#      26 try:
# ---> 27     import ultralytics
#      29     assert hasattr(ultralytics, "__version__")  # verify package is not directory
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\hub.py:647, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     637 if source == "github":
# ...

# %%
from ultralytics import YOLO

model = YOLO("C:/Users/jaisw/Downloads/yolov5s.pt")
# Out:
# PRO TIP  Replace 'model=C:/Users/jaisw/Downloads/yolov5s.pt' with new 'model=C:/Users/jaisw/Downloads/yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100%|██████████| 17.7M/17.7M [00:02<00:00, 8.42MB/s]

# %%
result = model.predict(r"C:\Users\jaisw\Downloads\download.jpeg", show=True)
# Out:
# image 1/1 C:\Users\jaisw\Downloads\download.jpeg: 640x512 1 person, 302.4ms
# Speed: 4.5ms preprocess, 302.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 512)

# %%
model
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (2): C3(
#         (cv1): Conv(
#           (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
# ...

# %%
# %matplotlib inline
plt.imshow(np.squeeze(result.render()))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 plt.imshow(np.squeeze(result.render()))
#       3 plt.show()
#
# AttributeError: 'list' object has no attribute 'render'

# %%
aa = result[0].plot()

# %%
rgb_image = cv2.cvtColor(aa, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image)

# %%
result2 = model("C:/Users/jaisw/Downloads/WhatsApp Image 2025-06-24 at 15.05.56_05b1628f.jpg")
bb = result2[0].plot()
rgbi = cv2.cvtColor(bb, cv2.COLOR_BGR2RGB)
plt.imshow(rgbi)
# Out:
# image 1/1 C:\Users\jaisw\Downloads\WhatsApp Image 2025-06-24 at 15.05.56_05b1628f.jpg: 640x480 1 person, 1 chair, 1 book, 278.0ms
# Speed: 4.8ms preprocess, 278.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
